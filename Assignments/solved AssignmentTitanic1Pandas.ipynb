# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'titanic_dataset.csv')

# %%
data=pd.DataFrame(df)
data.head()
# Out:
#    Unnamed: 0  pclass  survived  \
# 0           0       1         1
# 1           1       1         1
# 2           2       1         0
# 3           3       1         0
# 4           4       1         0
#
#                                               name  gender      age  sibsp  \
# 0                    Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                   Allison, Master. Hudson Trevor    male   0.9167      1
# 2                     Allison, Miss. Helen Loraine  female   2.0000      1
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
#
#    parch  ticket      fare    cabin embarked boat   body  \
# 0      0   24160  $211.34        B5        S    2    NaN
# 1      2  113781  $151.55   C22 C26        S   11    NaN
# 2      2  113781  $151.55   C22 C26        S  NaN    NaN
# 3      2  113781  $151.55   C22 C26        S  NaN  135.0
# ...

# %%
data.shape
# Out:
# (1309, 15)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'pclass', 'survived', 'name', 'gender', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body',
#        'home.dest'],
#       dtype='object')

# %%
data.describe()
# Out:
#         Unnamed: 0       pclass     survived          age        sibsp  \
# count  1309.000000  1309.000000  1309.000000  1046.000000  1309.000000
# mean    654.000000     2.294882     0.381971    29.881135     0.498854
# std     378.020061     0.837836     0.486055    14.413500     1.041658
# min       0.000000     1.000000     0.000000     0.166700     0.000000
# 25%     327.000000     2.000000     0.000000    21.000000     0.000000
# 50%     654.000000     3.000000     0.000000    28.000000     0.000000
# 75%     981.000000     3.000000     1.000000    39.000000     1.000000
# max    1308.000000     3.000000     1.000000    80.000000     8.000000
#
#              parch        body
# count  1309.000000  121.000000
# mean      0.385027  160.809917
# std       0.865560   97.696922
# min       0.000000    1.000000
# 25%       0.000000   72.000000
# 50%       0.000000  155.000000
# 75%       0.000000  256.000000
# max       9.000000  328.000000

# %%
df.isna()
# Out:
#       Unnamed: 0  pclass  survived   name  gender    age  sibsp  parch  \
# 0          False   False     False  False   False  False  False  False
# 1          False   False     False  False   False  False  False  False
# 2          False   False     False  False   False  False  False  False
# 3          False   False     False  False   False  False  False  False
# 4          False   False     False  False   False  False  False  False
# 5          False   False     False  False   False  False  False  False
# 6          False   False     False  False   False  False  False  False
# 7          False   False     False  False   False  False  False  False
# 8          False   False     False  False   False  False  False  False
# 9          False   False     False  False   False  False  False  False
# 10         False   False     False  False   False  False  False  False
# 11         False   False     False  False   False  False  False  False
# ...

# %%
data.isna().sum()/1309*100
# Out:
# Unnamed: 0     0.000000
# pclass         0.000000
# survived       0.000000
# name           0.000000
# gender         0.000000
# age           20.091673
# sibsp          0.000000
# parch          0.000000
# ticket         0.000000
# fare           0.076394
# cabin         77.463713
# embarked       0.152788
# boat          62.872422
# body          90.756303
# home.dest     43.086325
# dtype: float64

# %%
d.drop(columns=['cabin','boat','body','home.dest'],inplace=True)

# %%
data.head()
# Out:
#    Unnamed: 0  pclass  survived  \
# 0           0       1         1
# 1           1       1         1
# 2           2       1         0
# 3           3       1         0
# 4           4       1         0
#
#                                               name  gender      age  sibsp  \
# 0                    Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                   Allison, Master. Hudson Trevor    male   0.9167      1
# 2                     Allison, Miss. Helen Loraine  female   2.0000      1
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
#
#    parch  ticket      fare    cabin embarked boat   body  \
# 0      0   24160  $211.34        B5        S    2    NaN
# 1      2  113781  $151.55   C22 C26        S   11    NaN
# 2      2  113781  $151.55   C22 C26        S  NaN    NaN
# 3      2  113781  $151.55   C22 C26        S  NaN  135.0
# ...

# %%
data.shape
# Out:
# (1309, 15)

# %%
data.drop(columns=['cabin','boat','body','home.dest'],inplace=True)

# %%
data.drop(columns=['name','sibsp','parch','ticket'],inplace=True)

# %%
data.head()
# Out:
#    Unnamed: 0  pclass  survived  gender      age      fare embarked
# 0           0       1         1  female  29.0000  $211.34         S
# 1           1       1         1    male   0.9167  $151.55         S
# 2           2       1         0  female   2.0000  $151.55         S
# 3           3       1         0    male  30.0000  $151.55         S
# 4           4       1         0  female  25.0000  $151.55         S

# %%
data.drop(columns=['Unnamed: 0'],inplace=True)

# %%
data.head()
# Out:
#    pclass  survived  gender      age      fare embarked
# 0       1         1  female  29.0000  $211.34         S
# 1       1         1    male   0.9167  $151.55         S
# 2       1         0  female   2.0000  $151.55         S
# 3       1         0    male  30.0000  $151.55         S
# 4       1         0  female  25.0000  $151.55         S

# %%
data.dtypes
# Out:
# pclass        int64
# survived      int64
# gender       object
# age         float64
# fare         object
# embarked     object
# dtype: object

# %%
a=df.fare.str.replace('$','')

# %%
a.head()
# Out:
# 0    211.34
# 1    151.55
# 2    151.55
# 3    151.55
# 4    151.55
# Name: fare, dtype: object

# %%
col=a.astype(float)

# %%
data.fare=col

# %%
data.head()
# Out:
#    pclass  survived  gender      age    fare embarked
# 0       1         1  female  29.0000  211.34        S
# 1       1         1    male   0.9167  151.55        S
# 2       1         0  female   2.0000  151.55        S
# 3       1         0    male  30.0000  151.55        S
# 4       1         0  female  25.0000  151.55        S

# %%
data.dtypes
# Out:
# pclass        int64
# survived      int64
# gender       object
# age         float64
# fare        float64
# embarked     object
# dtype: object

# %%
data.isnull().sum()
# Out:
# pclass        0
# survived      0
# gender        0
# age         263
# fare          1
# embarked      2
# dtype: int64

# %%
b=data.age.mean()

# %%
data.age.fillna(b, inplace=True)

# %%
data.head()
# Out:
#    pclass  survived  gender      age    fare embarked
# 0       1         1  female  29.0000  211.34        S
# 1       1         1    male   0.9167  151.55        S
# 2       1         0  female   2.0000  151.55        S
# 3       1         0    male  30.0000  151.55        S
# 4       1         0  female  25.0000  151.55        S

# %%
data.isnull().sum()
# Out:
# pclass      0
# survived    0
# gender      0
# age         0
# fare        1
# embarked    2
# dtype: int64

# %%
c=data.fare.mean()

# %%
data.fare.fillna(b, inplace=True)

# %%
data.isnull().sum()
# Out:
# pclass      0
# survived    0
# gender      0
# age         0
# fare        0
# embarked    2
# dtype: int64

# %%
data.dropna(axis=0,inplace=True)

# %%
data.isnull().sum()
# Out:
# pclass      0
# survived    0
# gender      0
# age         0
# fare        0
# embarked    0
# dtype: int64

# %%
data.to_csv('titanic_filtered.csv')

# %%
pd.read_csv(r'titanic_filtered.csv')
# Out:
#       Unnamed: 0  pclass  survived  gender        age    fare embarked
# 0              0       1         1  female  29.000000  211.34        S
# 1              1       1         1    male   0.916700  151.55        S
# 2              2       1         0  female   2.000000  151.55        S
# 3              3       1         0    male  30.000000  151.55        S
# 4              4       1         0  female  25.000000  151.55        S
# 5              5       1         1    male  48.000000   26.55        S
# 6              6       1         1  female  63.000000   77.96        S
# 7              7       1         0    male  39.000000    0.00        S
# 8              8       1         1  female  53.000000   51.48        S
# 9              9       1         0    male  71.000000   49.50        C
# 10            10       1         0    male  47.000000  227.53        C
# 11            11       1         1  female  18.000000  227.53        C
# ...

# %%
d=data.survived.replace(0,'D')
#/a=df['survived'].replace({0:'D',1:'A'})

# %%
f=d.replace(1,'A')
print(f)
# Out:
# 0       A
# 1       A
# 2       D
# 3       D
# 4       D
# 5       A
# 6       A
# 7       D
# 8       A
# 9       D
# 10      D
# 11      A
# 12      A
# 13      A
# 14      A
# 15      D
# 16      D
# 17      A
# 18      A
# 19      D
# 20      A
# 21      A
# 22      A
# 23      A
# 24      A
# 25      D
# 26      A
# 27      A
# 28      A
# 29      A
#        ..
# 1279    D
# 1280    D
# 1281    D
# 1282    D
# 1283    D
# 1284    D
# 1285    D
# 1286    A
# 1287    D
# 1288    D
# 1289    D
# 1290    A
# 1291    D
# 1292    D
# 1293    D
# 1294    D
# 1295    D
# 1296    D
# 1297    D
# 1298    D
# 1299    D
# 1300    A
# 1301    D
# 1302    D
# 1303    D
# 1304    D
# 1305    D
# 1306    D
# 1307    D
# 1308    D
# Name: survived, Length: 1307, dtype: object

# %%
data.survived=f

# %%
data.head()
# Out:
#    pclass survived  gender      age    fare embarked
# 0       1        A  female  29.0000  211.34        S
# 1       1        A    male   0.9167  151.55        S
# 2       1        D  female   2.0000  151.55        S
# 3       1        D    male  30.0000  151.55        S
# 4       1        D  female  25.0000  151.55        S

# %%
data.survived.value_counts()
# Out:
# D    809
# A    498
# Name: survived, dtype: int64

# %%
data.groupby(['gender','survived']).count()
# Out:
#                  pclass  age  fare  embarked
# gender survived
# female A            337  337   337       337
#        D            127  127   127       127
# male   A            161  161   161       161
#        D            682  682   682       682

# %%
data.head()
# Out:
#    pclass survived  gender      age    fare embarked
# 0       1        A  female  29.0000  211.34        S
# 1       1        A    male   0.9167  151.55        S
# 2       1        D  female   2.0000  151.55        S
# 3       1        D    male  30.0000  151.55        S
# 4       1        D  female  25.0000  151.55        S

# %%
data.groupby(['gender','survived']).count()

# %%
data.pclass.value_counts()
# Out:
# 3    709
# 1    321
# 2    277
# Name: pclass, dtype: int64

# %%
data.pclass.value_counts()
# Out:
# 3    709
# 1    321
# 2    277
# Name: pclass, dtype: int64

# %%
data.age.count()
# Out:
# 1307

# %%
p=data.nlargest(5,'age')
print(p)
# Out:
#       pclass survived  gender   age   fare embarked
# 14         1        A    male  80.0  30.00        S
# 61         1        A  female  76.0  78.85        S
# 1235       3        D    male  74.0   7.78        S
# 9          1        D    male  71.0  49.50        C
# 135        1        D    male  71.0  34.65        C

# %%
p.gender.count()
# Out:
# 5

# %%
p.head(2)
# Out:
#     pclass survived  gender   age   fare embarked
# 14       1        A    male  80.0  30.00        S
# 61       1        A  female  76.0  78.85        S

# %%
res = data[(data.survived == 'A') & (data.gender== 'male')]
print(res.nlargest(1, 'age'))
# Out:
#     pclass survived gender   age  fare embarked
# 14       1        A   male  80.0  30.0        S

# %%
res = data[(data.survived == 'A') & (data.gender== 'female')]
print(res.nlargest(1, 'age'))
# Out:
#     pclass survived  gender   age   fare embarked
# 61       1        A  female  76.0  78.85        S

# %%
data.groupby('gender').age.mean()
# Out:
# gender
# female    28.795931
# male      30.430716
# Name: age, dtype: float64

# %%
data.head()
# Out:
#    pclass survived  gender      age    fare embarked
# 0       1        A  female  29.0000  211.34        S
# 1       1        A    male   0.9167  151.55        S
# 2       1        D  female   2.0000  151.55        S
# 3       1        D    male  30.0000  151.55        S
# 4       1        D  female  25.0000  151.55        S

# %%
data.groupby('survived').age.mean()
# Out:
# survived
# A    28.974711
# D    30.389368
# Name: age, dtype: float64
