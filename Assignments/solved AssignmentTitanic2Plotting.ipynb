# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_profiling

# %%
df=pd.read_csv(r'titanic_dataset.csv')
data=pd.DataFrame(df)
pandas_profiling.ProfileReport(data)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
print(df)
# Out:
#       Unnamed: 0  pclass  survived  gender        age    fare embarked
# 0              0       1         1  female  29.000000  211.34        S
# 1              1       1         1    male   0.916700  151.55        S
# 2              2       1         0  female   2.000000  151.55        S
# 3              3       1         0    male  30.000000  151.55        S
# 4              4       1         0  female  25.000000  151.55        S
# 5              5       1         1    male  48.000000   26.55        S
# 6              6       1         1  female  63.000000   77.96        S
# 7              7       1         0    male  39.000000    0.00        S
# 8              8       1         1  female  53.000000   51.48        S
# 9              9       1         0    male  71.000000   49.50        C
# 10            10       1         0    male  47.000000  227.53        C
# 11            11       1         1  female  18.000000  227.53        C
# ...

# %%
plt.hist(data.age)
# Out:
# (array([ 72.,  62., 274., 513., 160., 108.,  65.,  40.,  10.,   3.]),
#  array([ 0.1667 ,  8.15003, 16.13336, 24.11669, 32.10002, 40.08335,
#         48.06668, 56.05001, 64.03334, 72.01667, 80.     ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df.age, width=4)
# Out:
# (array([ 72.,  62., 274., 513., 160., 108.,  65.,  40.,  10.,   3.]),
#  array([ 0.1667 ,  8.15003, 16.13336, 24.11669, 32.10002, 40.08335,
#         48.06668, 56.05001, 64.03334, 72.01667, 80.     ]),
#  <a list of 10 Patch objects>)

# %%
a=data.pclass.value_counts() #data.pclass.value_counts().plot.bar()
print(a)
# Out:
# 3    709
# 1    321
# 2    277
# Name: pclass, dtype: int64

# %%
plt.bar(a.index,a.values)
# Out:
# <BarContainer object of 3 artists>

# %%
b=data.gender.value_counts() #data.gender.value_counts().plot.barh()
print(b)
# Out:
# male      843
# female    464
# Name: gender, dtype: int64

# %%
plt.barh(b.index,b.values)
# Out:
# <BarContainer object of 2 artists>

# %%
c=data.groupby(['gender','survived'])
print(c)

# %%
m=c.survived.count().plot.bar()
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(m)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
